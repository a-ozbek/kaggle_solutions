# %% [markdown]
# Ideas:
#
# * Add FFT channels to CNN (Tried, does not make much difference)
# * Finetune CNN (with SGD slow learning rate)
# * 5-fold CNN
# * Extract Features from CNN (before FC) and do XGB
# * TTA (tried, made it better)
# * More augmenting, additional 45, 135, 315 degrees
# * More augmenting, random rotations and flips
# * Predict test data and train with test
# * Train on all of the training data (no train-val split)
# * Try a different combination of combine predictions
# * Fine-tune on pre-trained models (Get rid of some top layers because input size is small)

# %%
import numpy as np
import pandas as pd
from skimage import transform
from keras.models import Sequential, load_model
from keras.layers import Conv2D, MaxPooling2D, Dense, Dropout, Flatten
from keras import losses, optimizers, callbacks
import xgboost as xgb
from sklearn.decomposition import PCA
from sklearn.pipeline import make_pipeline
from sklearn.model_selection import cross_validate, train_test_split
from scipy import fftpack
import matplotlib.pyplot as plt
# %matplotlib inline
RANDOM_SEED = 43
np.random.seed(RANDOM_SEED)
# Out:
# Using TensorFlow backend.
# /home/can/anaconda2/lib/python2.7/site-packages/sklearn/cross_validation.py:41: DeprecationWarning: This module was deprecated in version 0.18 in favor of the model_selection module into which all the refactored classes and functions are moved. Also note that the interface of the new CV iterators are different from that of this module. This module will be removed in 0.20.
#   "This module will be removed in 0.20.", DeprecationWarning)

# %% [markdown]
# # Create Dataset

# %%
# Train
df = pd.read_json('./data/train.json')
X_train, y_train = [], []
for im_band1, im_band2, label in zip(df['band_1'], df['band_2'], df['is_iceberg']):
    im_band1 = np.array(im_band1).reshape(75, 75, 1)
    im_band2 = np.array(im_band2).reshape(75, 75, 1)    
    # Preprocess
    im_band1 /= np.std(im_band1)
    im_band2 /= np.std(im_band2)    
    im = np.concatenate([im_band1, im_band2], axis=2)
    X_train.append(im)
    y_train.append(label)    
X_train = np.array(X_train)
y_train = np.array(y_train)
print 'X_train.shape:', X_train.shape
print 'y_train.shape:', y_train.shape
# Out:
# X_train.shape: (1604, 75, 75, 2)
# y_train.shape: (1604,)

# %%
# # Test
# df = pd.read_json('./data/test.json')
# X_test, y_test = [], []
# for im_band1, im_band2 in zip(df['band_1'], df['band_2']):
#     im_band1 = np.array(im_band1).reshape(75, 75, 1)
#     im_band2 = np.array(im_band2).reshape(75, 75, 1)
#     im_band1 /= np.std(im_band1)
#     im_band2 /= np.std(im_band2)    
#     im = np.concatenate([im_band1, im_band2], axis=2)
#     X_test.append(im)
#     y_test.append(label)    
# X_test = np.array(X_test)
# y_test = np.array(y_test)
# print 'X_test.shape:', X_test.shape
# print 'y_test.shape:', y_test.shape

# %% [markdown]
# ## Train - Val Split

# %%
X_train, X_val, y_train, y_val = train_test_split(X_train, y_train, test_size=0.2, random_state=RANDOM_SEED)
print 'X_train.shape:', X_train.shape
print 'X_val.shape:', X_val.shape
print 'y_train.shape:', y_train.shape
print 'y_val.shape:', y_val.shape
# Out:
# X_train.shape: (1283, 75, 75, 2)
# X_val.shape: (321, 75, 75, 2)
# y_train.shape: (1283,)
# y_val.shape: (321,)

# %% [markdown]
# ## Data Augmentation

# %%
def bypass(x):
    return x

def h_flip(x):
    return x[:, :, ::-1, :]

def v_flip(x):
    return x[:, ::-1, :, :]

def hv_flip(x):
    return h_flip(v_flip(x))

def rot90(x):
    return np.concatenate([np.expand_dims(transform.rotate(im, 90), axis=0) for im in x], axis=0)

def rot180(x):
    return np.concatenate([np.expand_dims(transform.rotate(im, 180), axis=0) for im in x], axis=0)

def rot270(x):
    return np.concatenate([np.expand_dims(transform.rotate(im, 270), axis=0) for im in x], axis=0)

def rot45(x):
    return np.concatenate([np.expand_dims(transform.rotate(im, 45, mode='reflect'), axis=0) for im in x], axis=0)

def rot135(x):
    return np.concatenate([np.expand_dims(transform.rotate(im, 135, mode='reflect'), axis=0) for im in x], axis=0)

def rot315(x):
    return np.concatenate([np.expand_dims(transform.rotate(im, 315, mode='reflect'), axis=0) for im in x], axis=0)

aug_funcs = [bypass, 
             h_flip, v_flip, hv_flip,
             rot90, rot180, rot270,
             rot45, rot135, rot315]

# %%
# Train
X_train = np.concatenate([func(X_train) for func in aug_funcs], axis=0)
y_train = np.concatenate([y_train] * len(aug_funcs))

# Validation
X_val = np.concatenate([func(X_val) for func in aug_funcs], axis=0)
y_val = np.concatenate([y_val] * len(aug_funcs))

# 
print 'X_train.shape:', X_train.shape
print 'y_train.shape:', y_train.shape
print 'X_val.shape:', X_val.shape
print 'y_val.shape:', y_val.shape
# Out:
# X_train.shape: (12830, 75, 75, 2)
# y_train.shape: (12830,)
# X_val.shape: (3210, 75, 75, 2)
# y_val.shape: (3210,)

# %%
im = X_train[300, ..., 0]
im_r = transform.resize(im, output_shape=(300, 300))
plt.imshow(im)

# %%
plt.imshow(im_r)

# %% [markdown]
# # Training

# %%
def get_model(input_shape):
    # Architecture
    model = Sequential()
    model.add(Conv2D(32, kernel_size=(3, 3),
                     activation='relu',
                     input_shape=input_shape))
    model.add(Conv2D(64, (3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))
    model.add(Conv2D(128, (3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))
    model.add(Conv2D(256, (3, 3), activation='relu'))
    model.add(MaxPooling2D(pool_size=(2, 2)))
    model.add(Dropout(0.25))
    model.add(Flatten())
    model.add(Dense(128, activation='relu'))
    model.add(Dropout(0.5))
    model.add(Dense(1, activation='sigmoid'))
    
    # Compile the model
    loss = losses.binary_crossentropy
    optimizer = optimizers.Adam()
    metrics = ['accuracy']
    model.compile(loss=loss, optimizer=optimizer, metrics=metrics)
    
    #     
    return model

# %%
model = get_model(input_shape=(75, 75, 2))

# %%
# Callbacks
MODEL_PATH = './models/model2.h5'
m_q = 'val_loss'
model_path = MODEL_PATH
check_pt = callbacks.ModelCheckpoint(filepath=model_path, monitor=m_q, save_best_only=True, verbose=1)
early_stop = callbacks.EarlyStopping(patience=8, monitor=m_q, verbose=1)
reduce_lr = callbacks.ReduceLROnPlateau(patience=2, factor=0.5, monitor=m_q, verbose=1)
callback_list = [check_pt, early_stop, reduce_lr]

model.fit(X_train, y_train, validation_data=(X_val, y_val), callbacks=callback_list, epochs=200)
# Out:
# Train on 12830 samples, validate on 3210 samples
# Epoch 1/200
# 12736/12830 [============================>.] - ETA: 0s - loss: 0.5504 - acc: 0.7057Epoch 00000: val_loss improved from inf to 0.45132, saving model to ./models/model2.h5
# 12830/12830 [==============================] - 8s - loss: 0.5500 - acc: 0.7058 - val_loss: 0.4513 - val_acc: 0.7891
# Epoch 2/200
# 12800/12830 [============================>.] - ETA: 0s - loss: 0.4149 - acc: 0.8123Epoch 00001: val_loss improved from 0.45132 to 0.35891, saving model to ./models/model2.h5
# 12830/12830 [==============================] - 7s - loss: 0.4147 - acc: 0.8122 - val_loss: 0.3589 - val_acc: 0.8293
# Epoch 3/200
# 12736/12830 [============================>.] - ETA: 0s - loss: 0.3864 - acc: 0.8249Epoch 00002: val_loss improved from 0.35891 to 0.34991, saving model to ./models/model2.h5
# 12830/12830 [==============================] - 7s - loss: 0.3863 - acc: 0.8251 - val_loss: 0.3499 - val_acc: 0.8324
# 12830/12830 [==============================] - 7s - loss: 0.1133 - acc: 0.9543 - val_loss: 0.2682 - val_acc: 0.8928
# Epoch 25/200
# 12768/12830 [============================>.] - ETA: 0s - loss: 0.1089 - acc: 0.9550Epoch 00024: val_loss did not improve
#
# Epoch 00024: reducing learning rate to 3.12500014843e-05.
# 12830/12830 [==============================] - 7s - loss: 0.1089 - acc: 0.9549 - val_loss: 0.2831 - val_acc: 0.8941
# Epoch 26/200
# 12736/12830 [============================>.] - ETA: 0s - loss: 0.1072 - acc: 0.9571Epoch 00025: val_loss did not improve
# 12830/12830 [==============================] - 7s - loss: 0.1071 - acc: 0.9571 - val_loss: 0.2770 - val_acc: 0.8919
# Epoch 27/200
# 12768/12830 [============================>.] - ETA: 0s - loss: 0.1057 - acc: 0.9591Epoch 00026: val_loss did not improve
#
# Epoch 00026: reducing learning rate to 1.56250007421e-05.
# 12830/12830 [==============================] - 7s - loss: 0.1056 - acc: 0.9591 - val_loss: 0.2794 - val_acc: 0.8882
# Epoch 00026: early stopping

# %%
# # Finetune
# loss = losses.binary_crossentropy
# optimizer = optimizers.SGD(lr=1e-4)
# metrics = ['accuracy']
# model.compile(loss=loss, optimizer=optimizer, metrics=metrics)

# %%
# m_q = 'val_loss'
# model_path = MODEL_PATH
# check_pt = callbacks.ModelCheckpoint(filepath=model_path, monitor=m_q, save_best_only=True, verbose=1)
# early_stop = callbacks.EarlyStopping(patience=5, monitor=m_q, verbose=1)
# reduce_lr = callbacks.ReduceLROnPlateau(patience=2, factor=0.33, monitor=m_q, verbose=1)
# callback_list = [check_pt, early_stop, reduce_lr]

# model.fit(X_train, y_train, validation_data=(X_val, y_val), callbacks=callback_list, epochs=200)

# %% [markdown]
# # Predict Test

# %%
# Load test data
df = pd.read_json('./data/test.json')
X_test, y_test = [], []
for im_band1, im_band2 in zip(df['band_1'], df['band_2']):
    im_band1 = np.array(im_band1).reshape(75, 75, 1)
    im_band2 = np.array(im_band2).reshape(75, 75, 1)   
    # Preprocess - zero mean
    im_band1 -= np.mean(im_band1)
    im_band2 -= np.mean(im_band2)    
    # Preprocess - normalize
    im_band1 /= np.std(im_band1)
    im_band2 /= np.std(im_band2)    
    im = np.concatenate([im_band1, im_band2], axis=2)
    X_test.append(im)    
X_test = np.array(X_test)
print 'X_test.shape:', X_test.shape
# Out:
# X_test.shape: (8424, 75, 75, 2)

# %%
# Load the model
MODEL_PATH = './models/model4/model3.h5'
model = load_model(MODEL_PATH)

# %%
# predict
y_test_p = model.predict(X_test, verbose=1)
# Out:
# 8416/8424 [============================>.] - ETA: 0s

# %%
# predict - tta
y_test_p = 0
for func in aug_funcs:
    y_test_p += model.predict(func(X_test), verbose=1).flatten()
y_test_p = y_test_p / len(aug_funcs)
# Out:
# 8256/8424 [============================>.] - ETA: 0s

# %%
df_sub = pd.DataFrame()
df_sub['id'] = df['id']
df_sub['is_iceberg'] = y_test_p.flatten()
df_sub.to_csv('./submissions/sub9.csv', index=False)
